# %%
# modules we'll use
import pandas as pd
import numpy as np

# read in all our data
nps_df = pd.read_csv("data/archive.csv")

nps_df.sample(4)
# Out:
#      Year   Category                                           Prize  \
# 352  1962  Chemistry               The Nobel Prize in Chemistry 1962
# 143  1928   Medicine  The Nobel Prize in Physiology or Medicine 1928
# 16   1903      Peace                      The Nobel Peace Prize 1903
# 265  1950      Peace                      The Nobel Peace Prize 1950
#
#                                             Motivation Prize Share  \
# 352  "for their studies of the structures of globul...         1/2
# 143                           "for his work on typhus"         1/1
# 16                                                 NaN         1/1
# 265                                                NaN         1/1
#
#      Laureate ID Laureate Type                    Full Name  Birth Date  \
# 352          227    Individual         John Cowdery Kendrew  1917-03-24
# 143          318    Individual  Charles Jules Henri Nicolle  1866-09-21
# 16           466    Individual        William Randal Cremer  1828-03-18
# 265          511    Individual                 Ralph Bunche  1904-08-07
#
#       Birth City             Birth Country   Sex  \
# 352       Oxford            United Kingdom  Male
# 143        Rouen                    France  Male
# 16       Fareham            United Kingdom  Male
# 265  Detroit, MI  United States of America  Male
#
#                        Organization Name Organization City  \
# 352  MRC Laboratory of Molecular Biology         Cambridge
# 143                     Institut Pasteur             Tunis
# 16                                   NaN               NaN
# 265                   Harvard University     Cambridge, MA
#
#          Organization Country  Death Date    Death City  \
# 352            United Kingdom  1997-08-23     Cambridge
# 143                       NaN  1936-02-28         Tunis
# 16                        NaN  1908-07-22        London
# 265  United States of America  1971-12-09  New York, NY
#
#                 Death Country
# 352            United Kingdom
# 143                   Tunisia
# 16             United Kingdom
# 265  United States of America

# %%
missing_values_count = nps_df.isnull().sum()
missing_values_count
# Out:
# Year                      0
# Category                  0
# Prize                     0
# Motivation               88
# Prize Share               0
# Laureate ID               0
# Laureate Type             0
# Full Name                 0
# Birth Date               29
# Birth City               28
# Birth Country            26
# Sex                      26
# Organization Name       247
# Organization City       253
# Organization Country    253
# Death Date              352
# Death City              370
# Death Country           364
# dtype: int64

# %%
# How many total missing values do we have?
# shape returns the dimentionality of a dataframe (rows and columns), can you guess what product will do?
total_cells_nfl = np.product(nps_df.shape) 
total_missing_nfl = missing_values_count.sum()

# percent of data that is missing
percentage_missign_values_nfl = (total_missing_nfl/total_cells_nfl) * 100
print(percentage_missign_values_nfl)
# Out:
# 11.672973282880404
